# %%
import numpy as np
import cv2

from tensorflow.keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D
from keras.optimizers import Adam
from keras.layers import MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator

# %%
train_dir = r"D:\data_science\train"
val_dir = r"D:\data_science\test"
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(48,48),
        batch_size=64,
        color_mode="grayscale",
        class_mode='categorical')

validation_generator = val_datagen.flow_from_directory(
        val_dir,
        target_size=(48,48),
        batch_size=64,
        color_mode="grayscale",
        class_mode='categorical')
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
emotion_model = Sequential()

emotion_model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48,48,1)))
emotion_model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Dropout(0.25))

emotion_model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Dropout(0.25))

emotion_model.add(Flatten())
emotion_model.add(Dense(1024, activation='relu'))
emotion_model.add(Dropout(0.5))
emotion_model.add(Dense(7, activation='softmax'))

# %%
emotion_model.compile(loss='categorical_crossentropy',optimizer=Adam(lr=0.0001, decay=1e-6),metrics=['accuracy'])

emotion_model_info = emotion_model.fit_generator(
        train_generator,
        steps_per_epoch=28709 // 64,
        epochs=60,
        validation_data=validation_generator,
        validation_steps=7178 // 64)
# Out:
# C:\Users\Manav\AppData\Local\Temp\ipykernel_10612\1239650706.py:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   emotion_model_info = emotion_model.fit_generator(
# Epoch 1/60
# 448/448 [==============================] - 737s 2s/step - loss: 1.8038 - accuracy: 0.2608 - val_loss: 1.7126 - val_accuracy: 0.3331
# Epoch 2/60
# 448/448 [==============================] - 306s 684ms/step - loss: 1.6260 - accuracy: 0.3663 - val_loss: 1.5395 - val_accuracy: 0.4230
# Epoch 3/60
# 448/448 [==============================] - 196s 437ms/step - loss: 1.5078 - accuracy: 0.4198 - val_loss: 1.4330 - val_accuracy: 0.4506
# Epoch 4/60
# 448/448 [==============================] - 367s 819ms/step - loss: 1.4303 - accuracy: 0.4557 - val_loss: 1.3887 - val_accuracy: 0.4658
# Epoch 5/60
# 448/448 [==============================] - 364s 811ms/step - loss: 1.3722 - accuracy: 0.4792 - val_loss: 1.3255 - val_accuracy: 0.4897
# Epoch 6/60
# 448/448 [==============================] - 182s 405ms/step - loss: 1.3210 - accuracy: 0.4984 - val_loss: 1.2880 - val_accuracy: 0.5067
# Epoch 7/60
# 448/448 [==============================] - 184s 411ms/step - loss: 1.2810 - accuracy: 0.5166 - val_loss: 1.2545 - val_accuracy: 0.5213
# Epoch 8/60
# 448/448 [==============================] - 184s 410ms/step - loss: 1.2482 - accuracy: 0.5292 - val_loss: 1.2487 - val_accuracy: 0.5227
# Epoch 9/60
# 448/448 [==============================] - 184s 410ms/step - loss: 1.2150 - accuracy: 0.5414 - val_loss: 1.2054 - val_accuracy: 0.5430
# Epoch 10/60
# 448/448 [==============================] - 185s 412ms/step - loss: 1.1842 - accuracy: 0.5533 - val_loss: 1.1868 - val_accuracy: 0.5509
# Epoch 11/60
# 448/448 [==============================] - 183s 409ms/step - loss: 1.1553 - accuracy: 0.5675 - val_loss: 1.1719 - val_accuracy: 0.5555
# Epoch 12/60
# 448/448 [==============================] - 184s 411ms/step - loss: 1.1301 - accuracy: 0.5759 - val_loss: 1.1502 - val_accuracy: 0.5678
# Epoch 13/60
# 448/448 [==============================] - 184s 411ms/step - loss: 1.1043 - accuracy: 0.5852 - val_loss: 1.1432 - val_accuracy: 0.5705
# Epoch 14/60
# 448/448 [==============================] - 187s 417ms/step - loss: 1.0825 - accuracy: 0.5946 - val_loss: 1.1484 - val_accuracy: 0.5650
# Epoch 15/60
# 448/448 [==============================] - 230s 514ms/step - loss: 1.0634 - accuracy: 0.6015 - val_loss: 1.1138 - val_accuracy: 0.5820
# Epoch 16/60
# 448/448 [==============================] - 230s 512ms/step - loss: 1.0374 - accuracy: 0.6134 - val_loss: 1.1275 - val_accuracy: 0.5741
# Epoch 17/60
# 448/448 [==============================] - 218s 486ms/step - loss: 1.0143 - accuracy: 0.6214 - val_loss: 1.0954 - val_accuracy: 0.5873
# Epoch 18/60
# 448/448 [==============================] - 200s 446ms/step - loss: 0.9930 - accuracy: 0.6314 - val_loss: 1.0895 - val_accuracy: 0.5919
# Epoch 19/60
# 448/448 [==============================] - 199s 444ms/step - loss: 0.9745 - accuracy: 0.6390 - val_loss: 1.0741 - val_accuracy: 0.5985
# Epoch 20/60
# 448/448 [==============================] - 199s 444ms/step - loss: 0.9543 - accuracy: 0.6495 - val_loss: 1.0707 - val_accuracy: 0.5995
# Epoch 21/60
# 448/448 [==============================] - 201s 449ms/step - loss: 0.9304 - accuracy: 0.6554 - val_loss: 1.0841 - val_accuracy: 0.6011
# Epoch 22/60
# 448/448 [==============================] - 205s 457ms/step - loss: 0.9118 - accuracy: 0.6617 - val_loss: 1.0729 - val_accuracy: 0.5992
# Epoch 23/60
# 448/448 [==============================] - 206s 460ms/step - loss: 0.8891 - accuracy: 0.6750 - val_loss: 1.0671 - val_accuracy: 0.6048
# Epoch 24/60
# 448/448 [==============================] - 205s 458ms/step - loss: 0.8684 - accuracy: 0.6827 - val_loss: 1.0593 - val_accuracy: 0.6110
# Epoch 25/60
# 448/448 [==============================] - 387s 865ms/step - loss: 0.8491 - accuracy: 0.6876 - val_loss: 1.0617 - val_accuracy: 0.6105
# Epoch 26/60
# 448/448 [==============================] - 343s 766ms/step - loss: 0.8274 - accuracy: 0.6940 - val_loss: 1.0705 - val_accuracy: 0.6088
# Epoch 27/60
# 448/448 [==============================] - 176s 394ms/step - loss: 0.8108 - accuracy: 0.7025 - val_loss: 1.0532 - val_accuracy: 0.6138
# Epoch 28/60
# 448/448 [==============================] - 194s 433ms/step - loss: 0.7903 - accuracy: 0.7105 - val_loss: 1.0580 - val_accuracy: 0.6123
# Epoch 29/60
# 448/448 [==============================] - 366s 817ms/step - loss: 0.7636 - accuracy: 0.7207 - val_loss: 1.0469 - val_accuracy: 0.6161
# Epoch 30/60
# 448/448 [==============================] - 222s 496ms/step - loss: 0.7429 - accuracy: 0.7320 - val_loss: 1.0594 - val_accuracy: 0.6158
# Epoch 31/60
# 448/448 [==============================] - 186s 415ms/step - loss: 0.7228 - accuracy: 0.7365 - val_loss: 1.0589 - val_accuracy: 0.6165
# Epoch 32/60
# 448/448 [==============================] - 189s 421ms/step - loss: 0.7021 - accuracy: 0.7424 - val_loss: 1.0532 - val_accuracy: 0.6223
# Epoch 33/60
# 448/448 [==============================] - 186s 416ms/step - loss: 0.6852 - accuracy: 0.7501 - val_loss: 1.0542 - val_accuracy: 0.6236
# Epoch 34/60
# 448/448 [==============================] - 186s 414ms/step - loss: 0.6651 - accuracy: 0.7555 - val_loss: 1.0519 - val_accuracy: 0.6272
# Epoch 35/60
# 448/448 [==============================] - 184s 412ms/step - loss: 0.6470 - accuracy: 0.7618 - val_loss: 1.0664 - val_accuracy: 0.6264
# Epoch 36/60
# 448/448 [==============================] - 185s 412ms/step - loss: 0.6268 - accuracy: 0.7728 - val_loss: 1.0652 - val_accuracy: 0.6275
# Epoch 37/60
# 448/448 [==============================] - 186s 416ms/step - loss: 0.6059 - accuracy: 0.7804 - val_loss: 1.0918 - val_accuracy: 0.6286
# Epoch 38/60
# 448/448 [==============================] - 191s 426ms/step - loss: 0.5906 - accuracy: 0.7859 - val_loss: 1.0708 - val_accuracy: 0.6290
# Epoch 39/60
# 448/448 [==============================] - 188s 420ms/step - loss: 0.5714 - accuracy: 0.7922 - val_loss: 1.0913 - val_accuracy: 0.6345
# Epoch 40/60
# 448/448 [==============================] - 178s 398ms/step - loss: 0.5555 - accuracy: 0.7990 - val_loss: 1.0809 - val_accuracy: 0.6260
# Epoch 41/60
# 448/448 [==============================] - 182s 407ms/step - loss: 0.5431 - accuracy: 0.8029 - val_loss: 1.1026 - val_accuracy: 0.6274
# Epoch 42/60
# 448/448 [==============================] - 185s 414ms/step - loss: 0.5202 - accuracy: 0.8124 - val_loss: 1.0993 - val_accuracy: 0.6318
# Epoch 43/60
# 448/448 [==============================] - 185s 412ms/step - loss: 0.5057 - accuracy: 0.8204 - val_loss: 1.1189 - val_accuracy: 0.6290
# Epoch 44/60
# 448/448 [==============================] - 185s 413ms/step - loss: 0.4911 - accuracy: 0.8227 - val_loss: 1.1133 - val_accuracy: 0.6309
# Epoch 45/60
# 448/448 [==============================] - 185s 413ms/step - loss: 0.4810 - accuracy: 0.8255 - val_loss: 1.1256 - val_accuracy: 0.6330
# Epoch 46/60
# 448/448 [==============================] - 185s 413ms/step - loss: 0.4543 - accuracy: 0.8334 - val_loss: 1.1240 - val_accuracy: 0.6314
# Epoch 47/60
# 448/448 [==============================] - 185s 413ms/step - loss: 0.4470 - accuracy: 0.8364 - val_loss: 1.1421 - val_accuracy: 0.6342
# Epoch 48/60
# 448/448 [==============================] - 185s 412ms/step - loss: 0.4333 - accuracy: 0.8433 - val_loss: 1.1439 - val_accuracy: 0.6367
# Epoch 49/60
# 448/448 [==============================] - 185s 413ms/step - loss: 0.4137 - accuracy: 0.8507 - val_loss: 1.1762 - val_accuracy: 0.6283
# Epoch 50/60
# 448/448 [==============================] - 185s 413ms/step - loss: 0.4116 - accuracy: 0.8519 - val_loss: 1.1752 - val_accuracy: 0.6345
# Epoch 51/60
# 448/448 [==============================] - 185s 412ms/step - loss: 0.3874 - accuracy: 0.8617 - val_loss: 1.1622 - val_accuracy: 0.6290
# Epoch 52/60
# 448/448 [==============================] - 186s 414ms/step - loss: 0.3789 - accuracy: 0.8634 - val_loss: 1.1993 - val_accuracy: 0.6336
# Epoch 53/60
# 448/448 [==============================] - 185s 412ms/step - loss: 0.3680 - accuracy: 0.8657 - val_loss: 1.1821 - val_accuracy: 0.6362
# Epoch 54/60
# 448/448 [==============================] - 207s 463ms/step - loss: 0.3599 - accuracy: 0.8719 - val_loss: 1.2117 - val_accuracy: 0.6335
# Epoch 55/60
# 448/448 [==============================] - 207s 462ms/step - loss: 0.3551 - accuracy: 0.8715 - val_loss: 1.2049 - val_accuracy: 0.6321
# Epoch 56/60
# 448/448 [==============================] - 360s 804ms/step - loss: 0.3466 - accuracy: 0.8744 - val_loss: 1.2206 - val_accuracy: 0.6296
# Epoch 57/60
# 448/448 [==============================] - 269s 600ms/step - loss: 0.3347 - accuracy: 0.8785 - val_loss: 1.2181 - val_accuracy: 0.6327
# Epoch 58/60
# 448/448 [==============================] - 205s 457ms/step - loss: 0.3319 - accuracy: 0.8814 - val_loss: 1.2323 - val_accuracy: 0.6395
# Epoch 59/60
# 448/448 [==============================] - 218s 487ms/step - loss: 0.3142 - accuracy: 0.8866 - val_loss: 1.2356 - val_accuracy: 0.6392
# Epoch 60/60
# 448/448 [==============================] - 208s 465ms/step - loss: 0.3075 - accuracy: 0.8908 - val_loss: 1.2297 - val_accuracy: 0.6334

# %%
emotion_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 46, 46, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 44, 44, 64)        18496
#
#  max_pooling2d (MaxPooling2D  (None, 22, 22, 64)       0
#  )
#
#  dropout (Dropout)           (None, 22, 22, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 20, 20, 128)       73856
#
#  max_pooling2d_1 (MaxPooling  (None, 10, 10, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 128)         147584
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 1024)              2098176
#
#  dropout_2 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 7)                 7175
#
# =================================================================
# Total params: 2,345,607
# Trainable params: 2,345,607
# Non-trainable params: 0
# _________________________________________________________________

# %%
model=emotion_model.save('model.h5')

# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model
model = load_model('model.h5')
cv2.ocl.setUseOpenCL(False)

emotion_dict = {0: "Angry", 1: "Disgusted", 2: "Fearful", 3: "Happy", 4: "Neutral", 5: "Sad", 6: "Surprised"}

cap = cv2.VideoCapture(0)
while True:
    ret, frame = cap.read()
    if not ret:
        break
    bounding_box = cv2.CascadeClassifier(r"C:\Users\Manav\AppData\Local\Programs\Python\Python310\Lib\site-packages\cv2\data\haarcascade_frontalface_default.xml")
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    num_faces = bounding_box.detectMultiScale(gray_frame,scaleFactor=1.3, minNeighbors=5)

    for (x, y, w, h) in num_faces:
        cv2.rectangle(frame, (x, y-50), (x+w, y+h+10), (255, 0, 0), 2)
        roi_gray_frame = gray_frame[y:y + h, x:x + w]
        cropped_img = np.expand_dims(np.expand_dims(cv2.resize(roi_gray_frame, (48, 48)), -1), 0)
        emotion_prediction = model.predict(cropped_img)
        maxindex = int(np.argmax(emotion_prediction))
        cv2.putText(frame, emotion_dict[maxindex], (x+20, y-60), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

    cv2.imshow('Video', cv2.resize(frame,(1200,860),interpolation = cv2.INTER_CUBIC))
    if cv2.waitKey(1) & 0xFF == ord('q'):
        cap.release()
        cv2.destroyAllWindows()
        break
# Out:
# 1/1 [==============================] - 0s 342ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
